# %%
import sys
import os
import matplotlib.pyplot as plt
import seaborn as sns


# Add the root directory to sys.path
sys.path.append(os.path.abspath('..'))

# %%
from scripts.eda import exploratory_data_analysis
file_path = '../data/MachineLearningRating_v3.txt'
eda = exploratory_data_analysis(file_path)
print(eda.data)
# Out:
# c:\Users\HP\Desktop\10 acd\week-3\scripts\eda.py:8: DtypeWarning: Columns (32,37) have mixed types. Specify dtype option on import or set low_memory=False.
#   self.data = pd.read_csv(filepath, delimiter='|')
#          UnderwrittenCoverID  PolicyID     TransactionMonth  IsVATRegistered  \
# 0                     145249     12827  2015-03-01 00:00:00             True
# 1                     145249     12827  2015-05-01 00:00:00             True
# 2                     145249     12827  2015-07-01 00:00:00             True
# 3                     145255     12827  2015-05-01 00:00:00             True
# 4                     145255     12827  2015-07-01 00:00:00             True
# ...                      ...       ...                  ...              ...
# 1000093                31520       389  2015-04-01 00:00:00            False
# 1000094                31520       389  2015-06-01 00:00:00            False
# ...

# %%
eda.missing_values()
# Out:
# The missing value count for each column:
# UnderwrittenCoverID               0
# PolicyID                          0
# TransactionMonth                  0
# IsVATRegistered                   0
# Citizenship                       0
# LegalType                         0
# Title                             0
# Language                          0
# Bank                         145961
# AccountType                   40232
# MaritalStatus                  8259
# Gender                         9536
# Country                           0
# Province                          0
# PostalCode                        0
# MainCrestaZone                    0
# SubCrestaZone                     0
# ItemType                          0
# mmcode                          552
# VehicleType                     552
# RegistrationYear                  0
# make                            552
# Model                           552
# Cylinders                       552
# cubiccapacity                   552
# ...

# %%
eda.handle_missing_values()
# Out:
# c:\Users\HP\Desktop\10 acd\week-3\week-3\Lib\site-packages\numpy\lib\_nanfunctions_impl.py:1214: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# UnderwrittenCoverID               0
# PolicyID                          0
# TransactionMonth                  0
# IsVATRegistered                   0
# Citizenship                       0
# LegalType                         0
# Title                             0
# Language                          0
# Bank                              0
# AccountType                       0
# MaritalStatus                     0
# Gender                            0
# Country                           0
# Province                          0
# PostalCode                        0
# MainCrestaZone                    0
# SubCrestaZone                     0
# ItemType                          0
# mmcode                            0
# VehicleType                       0
# RegistrationYear                  0
# ...

# %%
eda.show_outliers("TotalPremium")
eda.show_outliers("TotalClaims")
# Out:
# Number of outliers in TotalPremium: 209042
# Outlier values in TotalPremium:
#          TotalPremium
# 3          512.848070
# 13         458.051613
# 14         709.980000
# 15         709.980000
# 16         526.759355
# ...               ...
# 1000091    347.235175
# 1000092    347.235175
# 1000093    347.235175
# 1000094    347.235175
# 1000095    347.235175
#
# [209042 rows x 1 columns]
# Number of outliers in TotalClaims: 2793
# Outlier values in TotalClaims:
#           TotalClaims
# 203       2294.096491
# 284       2040.473684
# 1560     46492.211754
# 1779     26516.859649
# 1943      6140.350877
# ...               ...
# 998512    7996.535088
# 998848   40011.859649
# 999218  101812.517544
# 999701  155317.578947
# 999923   28903.850877
#
# [2793 rows x 1 columns]

# %%
eda.handle_outliers('TotalPremium')
eda.handle_outliers('TotalClaims')
# Out:
# ('success',
#           UnderwrittenCoverID  PolicyID     TransactionMonth  IsVATRegistered  \
#  0                     145249     12827  2015-03-01 00:00:00             True
#  1                     145249     12827  2015-05-01 00:00:00             True
#  2                     145249     12827  2015-07-01 00:00:00             True
#  4                     145255     12827  2015-07-01 00:00:00             True
#  5                     145247     12827  2015-01-01 00:00:00             True
#  ...                      ...       ...                  ...              ...
#  1000081                31512       389  2015-07-01 00:00:00            False
#  1000082                31524       389  2014-07-01 00:00:00            False
#  1000083                31524       389  2015-02-01 00:00:00            False
#  1000096                31519       389  2014-07-01 00:00:00            False
#  1000097                31519       389  2015-02-01 00:00:00            False
#
# ...

# %%
eda._basic_columns_ploting('TotalPremium','TotalClaims')

# %%
eda.two_columns_scatter_plot('TotalPremium','TotalClaims')

# %%
eda.two_columns_scatter_plot('TotalPremium','TotalClaims')

# %% [markdown]
# the next step is the univaret analysis

# %%
eda.Univariate_analysis('TotalPremium')

# %% [markdown]
#  The next step is Bivariate analysis

# %%
eda.Bivariate_analysis('TotalPremium','TotalClaims')

# %%
print(eda.data[['TotalClaims', 'TotalPremium']].describe())
# Out:
#        TotalClaims   TotalPremium
# count     790093.0  790093.000000
# mean           0.0       4.303201
# std            0.0       8.758252
# min            0.0     -31.267685
# 25%            0.0       0.000000
# 50%            0.0       0.805702
# 75%            0.0       4.162719
# max            0.0      54.774503

# %%
# Avoid divide-by-zero error
eda.data['LossRatio'] = eda.data.apply(
    lambda row: row['TotalClaims'] / row['TotalPremium'] if row['TotalPremium'] > 0 else 0, axis=1
)

# %%
eda.time_series_trend_plot("TransactionMonth", "TotalClaims")

# %%
# 9. Correlation
eda.plot_correlation_heatmap()

# %%
eda.data.to_csv('../data/data.csv',index=False)
